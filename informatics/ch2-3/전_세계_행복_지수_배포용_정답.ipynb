# %% [markdown]
# # 정답 노트북

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('world_happiness_report_2021.csv')
df.head()

# %%
print(df.shape)
print(df.info())

# %%
print(df['Ladder score'].describe())
print(df.sort_values('Ladder score', ascending=False).head(10))
